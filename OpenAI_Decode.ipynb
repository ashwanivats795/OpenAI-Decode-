# %% [markdown]
# # OpenAI Decode Project
# Let's Analyze the data...

# %%
with open("finaldata.txt", encoding = 'utf-8') as f:
    data = f.read()

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c)>3]

# %%
def parse_chunk(chunk):
        chunk = chunk.strip()
        sep_chunk = chunk.split('\n')
        username = sep_chunk[0]
        no_of_posts = int(sep_chunk[1].split(" post")[0].replace(",", ""))
        no_of_followers = float(sep_chunk[2].split("follower")[0].replace(",","").replace("K","").replace("M",""))
        if("K" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000)
        elif("M" in sep_chunk[2]):
            no_of_followers = int(no_of_followers *1000000)
        else :
            no_of_followers = int(no_of_followers)


        no_of_following = float(sep_chunk[3].split("following")[0].replace(",","").replace("K","").replace("M",""))
        if("K" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000)
        elif("M" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000000)
        else :
            no_of_following = int(no_of_following)


        name = sep_chunk[4]
        if(len(sep_chunk)>5):
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else :
            type_of_page = "Unknown"
            bio = ""
        return {"username" : username, "no_of_posts" : no_of_posts, "no_of_followers" : no_of_followers,
            "no_of_following": no_of_following, "type_of_page": type_of_page, "bio" : bio}

# %%
all_chunks = [] 
for chunk in chunks:  
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk) 
print(all_chunks)
# Out:
# [{'username': 'techie_koramangala', 'no_of_posts': 420, 'no_of_followers': 9800, 'no_of_following': 310, 'type_of_page': 'Software Engineer', 'bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}, {'username': 'blrcoder_girl', 'no_of_posts': 150, 'no_of_followers': 6300, 'no_of_following': 120, 'type_of_page': 'Tech Creator', 'bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}, {'username': 'hsr_startup_stories', 'no_of_posts': 980, 'no_of_followers': 22400, 'no_of_following': 95, 'type_of_page': 'Media', 'bio': '🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com'}, {'username': 'cloud_dev_blr', 'no_of_posts': 210, 'no_of_followers': 4500, 'no_of_following': 60, 'type_of_page': 'Engineer', 'bio': '☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud'}, {'username': 'koramangala_coffee_lover', 'no_of_posts': 300, 'no_of_followers': 7900, 'no_of_following': 180, 'type_of_page': 'Cafe Explorer', 'bio': '☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter'}, {'username': 'ai_bangalore_news', 'no_of_posts': 1340, 'no_of_followers': 38000, 'no_of_following': 200, 'type_of_page': 'Media', 'bio': '🤖 Daily AI news from India\n📢 Startup & research updates\naibanglore.ai/news'}, {'username': 'techfounder_india', 'no_of_posts': 210, 'no_of_followers': 19000, 'no_of_following': 450, 'type_of_page': 'Founder', 'bio': '⚡ Building SaaS in Fintech\n📍 Indiranagar\ndevpatel.io'}, {'username': 'coder_on_orr', 'no_of_posts': 65, 'no_of_followers': 1900, 'no_of_following': 70, 'type_of_page': 'Backend Developer', 'bio': '🐍 Python | FastAPI enthusiast\n🌧️ Surviving ORR traffic\ngithub.com/sriramworks'}, {'username': 'blrdatascience_daily', 'no_of_posts': 540, 'no_of_followers': 15100, 'no_of_following': 150, 'type_of_page': 'Media', 'bio': '📊 Data + AI + ML\n👩\u200d🏫 Tutorials | Job alerts\nblrdatascience.in'}, {'username': 'frontend_with_megha', 'no_of_posts': 175, 'no_of_followers': 8200, 'no_of_following': 95, 'type_of_page': 'Frontend Dev', 'bio': '🎨 React | Next.js | UI Tips\n🌸 Bengaluru\nmeghacodes.dev'}, {'username': 'cubbonpark_runner', 'no_of_posts': 95, 'no_of_followers': 1500, 'no_of_following': 40, 'type_of_page': 'Lifestyle', 'bio': '🏃 Running after coding\n📍 Cubbon Park\nstrava.com/amanrunning'}, {'username': 'indiranagar_food_maps', 'no_of_posts': 600, 'no_of_followers': 12300, 'no_of_following': 155, 'type_of_page': 'Food & Drink', 'bio': '🍜 Maps of best places around Indiranagar\n📍 Bangalore\nfoodmapsblr.com'}, {'username': 'python_blr_jobs', 'no_of_posts': 1200, 'no_of_followers': 21000, 'no_of_following': 18, 'type_of_page': 'Community', 'bio': '💼 Python/ML/AI jobs daily\n📍 Bengaluru\npythonblr.jobs'}, {'username': 'sarjapur_coder', 'no_of_posts': 143, 'no_of_followers': 3200, 'no_of_following': 52, 'type_of_page': 'Full-stack Dev', 'bio': '🧑\u200d💻 MERN | DevTools\nCurrently debugging from Sarjapur\nroshancodes.dev'}, {'username': 'open_source_blr', 'no_of_posts': 300, 'no_of_followers': 9100, 'no_of_following': 78, 'type_of_page': 'Community', 'bio': '🌐 Meetups | Talks | OSS\ngithub.com/blropensource'}, {'username': 'techwalk_blr', 'no_of_posts': 430, 'no_of_followers': 11000, 'no_of_following': 320, 'type_of_page': 'Media', 'bio': '🚶 Exploring tech parks & cafes\n📍 Ecoworld | Manyata | Bagmane\ntechwalkblr.com'}, {'username': 'itpl_daily', 'no_of_posts': 590, 'no_of_followers': 14200, 'no_of_following': 210, 'type_of_page': 'Blog', 'bio': '🏢 Inside Whitefield Tech Life\n🚌 Bus stand stories included\nmedium.com/@itpldaily'}, {'username': 'react_native_blr', 'no_of_posts': 220, 'no_of_followers': 4700, 'no_of_following': 60, 'type_of_page': 'Community', 'bio': '📱 React Native Tips | Meetups\nrnblr.dev'}, {'username': 'founder_doodles', 'no_of_posts': 80, 'no_of_followers': 2300, 'no_of_following': 20, 'type_of_page': 'Artist + Coder', 'bio': '✏️ Startup doodles\n ...

# %% [markdown]
# # Who has the maximum posts?
# lets's write code to find max posts

# %%
import json
s = json.dumps(all_chunks, indent=4)  
with open("data.json", "w") as f:
    f.write(s)

# %%
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_post = chunk
print(chunk_with_max_post['username'])
# Out:
# startuphub_blr

# %% [markdown]
# # Who has the maximum followers?
# Lets write code to find who has max followers

# %%
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_followers']):
        max = chunk['no_of_followers']
        chunk_with_max_followers = chunk
print(chunk_with_max_followers['username'])
# Out:
# _anujsinghal

# %% [markdown]
# # Who follows maximum people?
# Lets write code to find who follows maximum people

# %%
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_following']):
        max = chunk['no_of_following']
        chunk_with_max_following = chunk
print(chunk_with_max_following['username'])
# Out:
# bangalore_tech_bro

# %% [markdown]
# # How many categories?
# Lets write code to find out number of categories

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(f"There are {len(categories)} categories")
# Out:
# There are 34 categories
